# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from fake import LinearRegression
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# <span style="font-size:30px">load data</span>

# %%
data = pd.read_csv("financial_regression.csv")

# %% [markdown]
# ## looking inside data

# %% [markdown]
# <span style="font-size:20px "> return information of your data </span>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3904 entries, 0 to 3903
# Data columns (total 47 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date                3904 non-null   object
#  1   sp500 open          3719 non-null   float64
#  2   sp500 high          3719 non-null   float64
#  3   sp500 low           3719 non-null   float64
#  4   sp500 close         3719 non-null   float64
#  5   sp500 volume        3719 non-null   float64
#  6   sp500 high-low      3719 non-null   float64
#  7   nasdaq open         3719 non-null   float64
#  8   nasdaq high         3719 non-null   float64
#  9   nasdaq low          3719 non-null   float64
#  10  nasdaq close        3719 non-null   float64
#  11  nasdaq volume       3719 non-null   float64
#  12  nasdaq high-low     3719 non-null   float64
#  13  us_rates_%          176 non-null    float64
#  14  CPI                 176 non-null    float64
# ...

# %%
data.describe()

# %%
data.drop(["GDP","CPI","us_rates_%"],axis=1)
data.dropna()
data["sp500 open"].isna().sum()

# %% [markdown]
# <span style="font-size:20px"> print 5 rows of data </span>

# %%
data.head()

# %% [markdown]
# <p style="font-size:20px ; color:red">here for delete a NaN data or infinte data</p>
# <p style="font-size:15px ; color:blue">data.dropna()</p>

# %%
data["sp500 open"]=data["sp500 open"].astype(int)

# %% [markdown]
# <span style="font-size:20px ">show data types in table </span>

# %%
data.dtypes

# %% [markdown]
# ## Data summarization

# %%
data[["sp500 open","sp500 close"]].agg(["mean","std"])
# Out:
#       sp500 open  sp500 close
# mean  268.399897   268.445118
# std   121.150274   121.165512

# %%
data.groupby("date").agg(mean_sp500=("sp500 open","mean"),
                         std_sp500=("sp500 open","std"),
                         mean_sp500_close=("sp500 close","mean"),
                         std_sp500_close=("sp500 close","std"))
# Out:
#             mean_sp500  std_sp500  mean_sp500_close  std_sp500_close
# date
# 2010-01-14      114.49        NaN            114.93              NaN
# 2010-01-15      114.73        NaN            113.64              NaN
# 2010-01-19      113.62        NaN            115.06              NaN
# 2010-01-20      114.28        NaN            113.89              NaN
# 2010-01-21      113.92        NaN            111.70              NaN
# ...                ...        ...               ...              ...
# 2024-10-11      576.05        NaN            579.58              NaN
# 2024-10-15      584.59        NaN            579.78              NaN
# 2024-10-16      579.78        NaN            582.30              NaN
# 2024-10-17      585.91        NaN            582.35              NaN
# 2024-10-18      584.07        NaN            584.59              NaN
#
# [3677 rows x 4 columns]

# %% [markdown]
# ## visualiztion

# %%
sns.histplot(data=data , x="sp500 open")
plt.show()

# %%
sns.boxplot(data=data , y="gold close")
# Out:
# <Axes: ylabel='gold close'>

# %%
sns.barplot(data=data[:5] , y="gold open")
# Out:
# <Axes: ylabel='gold open'>

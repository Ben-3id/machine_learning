# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler
from scipy.stats import multivariate_normal
from fake import Gaussian as G
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix as CM
data=pd.read_csv('D:\\coding\\fake_ML\\Files\\data_10.csv').drop(['010-000-024-033','010-000-030-096','020-000-032-221','020-000-033-111'],axis=1)
'''training data set'''
# Out:
# 'training data set'

# %%
X=data[data['anomaly']==0]
X_train=X[:4500].drop(['anomaly'],axis=1)
y_train=X.loc[4500:,['anomaly']]


X_test=(data[4500:].drop(['anomaly'],axis=1))
y_test=(data.loc[4500:,['anomaly']])

# %%
scaler = StandardScaler()
X_train = (scaler.fit_transform(X_train))
X_test= scaler.transform(X_test)

# %%
model=G()
model.fit(X_train,y_train)
print(classification_report(y_test,model.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.98      0.95      1298
#          1.0       0.85      0.49      0.62       235
#
#     accuracy                           0.91      1533
#    macro avg       0.88      0.74      0.79      1533
# weighted avg       0.90      0.91      0.90      1533
